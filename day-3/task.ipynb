# %% [markdown]
# #BASIC

# %%
# %sql

-- 1 
CREATE TABLE cyntexa_dev.sales.customer AS
SELECT * FROM read_files("/Volumes/cyntexa_dev/sales/raw/customers_raw.csv")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- 2
SELECT 
code,
name.forename AS first_name,
name.surname AS last_name,
nationality,
dob 
FROM read_files("/Volumes/dev/demo/raw-1000-richest/drivers.json",format => "json" , multiline => true)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>code</th><th>first_name</th><th>last_name</th><th>nationality</th><th>dob</th></tr></thead><tbody><tr><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>British</td><td>1985-01-07</td></tr><tr><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>German</td><td>1977-05-10</td></tr><tr><td>ROS</td><td>Nico</td><td>Rosberg</td><td>German</td><td>1985-06-27</td></tr><tr><td>ALO</td><td>Fernando</td><td>Alonso</td><td>Spanish</td><td>1981-07-29</td></tr><tr><td>KOV</td><td>Heikki</td><td>Kovalainen</td><td>Finnish</td><td>1981-10-19</td></tr><tr><td>NAK</td><td>Kazuki</td><td>Nakajima</td><td>Japanese</td><td>1985-01-11</td></tr><tr><td>BOU</td><td>Sébastien</td><td>Bourdais</td><td>French</td><td>1979-02-28</td></tr><tr><td>RAI</td><td>Kimi</td><td>Räikkönen</td><td>Finnish</td><td>1979-10-17</td></tr><tr><td>KUB</td><td>Robert</td><td>Kubica</td><td>Polish</td><td>1984-12-07</td></tr><tr><td>GLO</td><td>Timo</td><td>Glock</td><td>German</td><td>1982-03-18</td></tr><tr><td>SAT</td><td>Takuma</td><td>Sato</td><td>Japanese</td><td>1977-01-28</td></tr><tr><td>PIQ</td><td>Nelson</td><td>Piquet Jr.</td><td>Brazilian</td><td>1985-07-25</td></tr><tr><td>MAS</td><td>Felipe</td><td>Massa</td><td>Brazilian</td><td>1981-04-25</td></tr><tr><td>COU</td><td>David</td><td>Coulthard</td><td>British</td><td>1971-03-27</td></tr><tr><td>TRU</td><td>Jarno</td><td>Trulli</td><td>Italian</td><td>1974-07-13</td></tr><tr><td>SUT</td><td>Adrian</td><td>Sutil</td><td>German</td><td>1983-01-11</td></tr><tr><td>WEB</td><td>Mark</td><td>Webber</td><td>Australian</td><td>1976-08-27</td></tr><tr><td>BUT</td><td>Jenson</td><td>Button</td><td>British</td><td>1980-01-19</td></tr><tr><td>DAV</td><td>Anthony</td><td>Davidson</td><td>British</td><td>1979-04-18</td></tr><tr><td>VET</td><td>Sebastian</td><td>Vettel</td><td>German</td><td>1987-07-03</td></tr><tr><td>FIS</td><td>Giancarlo</td><td>Fisichella</td><td>Italian</td><td>1973-01-14</td></tr><tr><td>BAR</td><td>Rubens</td><td>Barrichello</td><td>Brazilian</td><td>1972-05-23</td></tr><tr><td>SCH</td><td>Ralf</td><td>Schumacher</td><td>German</td><td>1975-06-30</td></tr><tr><td>LIU</td><td>Vitantonio</td><td>Liuzzi</td><td>Italian</td><td>1980-08-06</td></tr><tr><td>WUR</td><td>Alexander</td><td>Wurz</td><td>Austrian</td><td>1974-02-15</td></tr><tr><td>SPE</td><td>Scott</td><td>Speed</td><td>American</td><td>1983-01-24</td></tr><tr><td>ALB</td><td>Christijan</td><td>Albers</td><td>Dutch</td><td>1979-04-16</td></tr><tr><td>WIN</td><td>Markus</td><td>Winkelhock</td><td>German</td><td>1980-06-13</td></tr><tr><td>YAM</td><td>Sakon</td><td>Yamamoto</td><td>Japanese</td><td>1982-07-09</td></tr><tr><td>MSC</td><td>Michael</td><td>Schumacher</td><td>German</td><td>1969-01-03</td></tr><tr><td>MON</td><td>Juan</td><td>Pablo Montoya</td><td>Colombian</td><td>1975-09-20</td></tr><tr><td>KLI</td><td>Christian</td><td>Klien</td><td>Austrian</td><td>1983-02-07</td></tr><tr><td>TMO</td><td>Tiago</td><td>Monteiro</td><td>Portuguese</td><td>1976-07-24</td></tr><tr><td>IDE</td><td>Yuji</td><td>Ide</td><td>Japanese</td><td>1975-01-21</td></tr><tr><td>VIL</td><td>Jacques</td><td>Villeneuve</td><td>Canadian</td><td>1971-04-09</td></tr><tr><td>FMO</td><td>Franck</td><td>Montagny</td><td>French</td><td>1978-01-05</td></tr><tr><td>DLR</td><td>Pedro</td><td>de la Rosa</td><td>Spanish</td><td>1971-02-24</td></tr><tr><td>DOO</td><td>Robert</td><td>Doornbos</td><td>Dutch</td><td>1981-09-23</td></tr><tr><td>KAR</td><td>Narain</td><td>Karthikeyan</td><td>Indian</td><td>1977-01-14</td></tr><tr><td>FRI</td><td>Patrick</td><td>Friesacher</td><td>Austrian</td><td>1980-09-26</td></tr><tr><td>ZON</td><td>Ricardo</td><td>Zonta</td><td>Brazilian</td><td>1976-03-23</td></tr><tr><td>PIZ</td><td>Antônio</td><td>Pizzonia</td><td>Brazilian</td><td>1980-09-11</td></tr><tr><td>\N</td><td>Cristiano</td><td>da Matta</td><td>Brazilian</td><td>1973-09-19</t ...

# %%
# %sql
-- 3
DESCRIBE cyntexa_dev.sales.customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customer_id</td><td>int</td><td>A unique identifier assigned to each customer, facilitating easy tracking and management of customer data.</td></tr><tr><td>name</td><td>string</td><td>The full name of the customer, which is essential for personalizing communications and maintaining customer relations.</td></tr><tr><td>email</td><td>string</td><td>The email address of the customer, used for correspondence and marketing purposes.</td></tr><tr><td>city</td><td>string</td><td>The city where the customer resides, helping to analyze geographic distribution and target local marketing efforts.</td></tr><tr><td>state</td><td>string</td><td>The state of residence for the customer, providing further insight into the customer's location for demographic analysis.</td></tr><tr><td>signup_date</td><td>date</td><td>The date when the customer registered, tracking onboarding trends and measuring time since signup.</td></tr><tr><td>phone</td><td>bigint</td><td>The contact phone number of the customer, necessary for direct communication and support.</td></tr><tr><td>_rescued_data</td><td>string</td><td>Holds any additional data that was recovered, which may not fit the standard customer profile but is still relevant.</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED cyntexa_dev.sales.customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>customer_id</td><td>int</td><td>A unique identifier assigned to each customer, facilitating easy tracking and management of customer data.</td></tr><tr><td>name</td><td>string</td><td>The full name of the customer, which is essential for personalizing communications and maintaining customer relations.</td></tr><tr><td>email</td><td>string</td><td>The email address of the customer, used for correspondence and marketing purposes.</td></tr><tr><td>city</td><td>string</td><td>The city where the customer resides, helping to analyze geographic distribution and target local marketing efforts.</td></tr><tr><td>state</td><td>string</td><td>The state of residence for the customer, providing further insight into the customer's location for demographic analysis.</td></tr><tr><td>signup_date</td><td>date</td><td>The date when the customer registered, tracking onboarding trends and measuring time since signup.</td></tr><tr><td>phone</td><td>bigint</td><td>The contact phone number of the customer, necessary for direct communication and support.</td></tr><tr><td>_rescued_data</td><td>string</td><td>Holds any additional data that was recovered, which may not fit the standard customer profile but is still relevant.</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>city, name, customer_id, _rescued_data, signup_date, phone, email, state</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>cyntexa_dev</td><td></td></tr><tr><td>Database</td><td>sales</td><td></td></tr><tr><td>Table</td><td>customer</td><td></td></tr><tr><td>Created Time</td><td>Mon Aug 24 07:17:27 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>27596 bytes, 1000 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Comment</td><td>The table contains information about customers, including their identification details and contact information. It can be used for managing customer relationships, analyzing customer demographics, and tracking customer signup trends. The data includes customer IDs, names, emails, locations, signup dates, and phone numbers.</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sakshijain7945@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.parquet.format.version=2.12.0,delta.parquet.format.version.afe.internal=2.12.0]</td><td></td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL cyntexa_dev.sales.customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>c2d390cf-994f-47a0-83bf-faf2c56a40e0</td><td>cyntexa_dev.sales.customer</td><td>The table contains information about customers, including their identification details and contact information. It can be used for managing customer relationships, analyzing customer demographics, and tracking customer signup trends. The data includes customer IDs, names, emails, locations, signup dates, and phone numbers.</td><td></td><td>2026-08-24T07:17:25.247Z</td><td>2026-08-24T07:19:29.000Z</td><td>List()</td><td>List()</td><td>1</td><td>27596</td><td>Map(delta.parquet.format.version -> 2.12.0, delta.parquet.format.version.afe.internal -> 2.12.0, delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# - DESCRIBE - it only shows the column and it s datatype with comments of a table
#
# - DESCRIBE EXTENDED -
# It shows the details of catalog,schema,location,table type like managed,external,created_date .
#
# - DESCRIBE DETAIL -
# It shows the table details like number of parquet files present , and more detail.

# %% [markdown]
# #INTERMEDIATE

# %%
# %sql
-- 4 - Add metadata
SELECT *,_metadata.file_name,_metadata.file_path
FROM cyntexa_dev.sales.customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th>email</th><th>city</th><th>state</th><th>signup_date</th><th>phone</th><th>_rescued_data</th><th>file_name</th><th>file_path</th></tr></thead><tbody><tr><td>1</td><td>Liam Chaudry</td><td>bakshianvi@example.org</td><td>Gudivada</td><td>Maharashtra</td><td>2024-08-25</td><td>3389083863</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Nachiket Kale</td><td>duttapahal@example.com</td><td>Kota</td><td>Assam</td><td>2025-05-06</td><td>5940781618</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Bimala Buch</td><td>ekarajbath@example.net</td><td>Salem</td><td>Madhya Pradesh</td><td>2025-02-21</td><td>2553419283</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Diya Rattan</td><td>theodore50@example.org</td><td>Amritsar</td><td>Gujarat</td><td>2026-05-31</td><td>3767242388</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Gavin Batta</td><td>opathak@example.org</td><td>Jamnagar</td><td>Rajasthan</td><td>2024-11-26</td><td>9166978480</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Aarush Lall</td><td>isaac46@example.org</td><td>Guna</td><td>Bihar</td><td>2026-04-30</td><td>8932528809</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Wridesh Brar</td><td>patildamyanti@example.org</td><td>Shivpuri</td><td>Uttarakhand</td><td>2024-09-21</td><td>2782489638</td><td>null</td><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/19aad3b7-09b7-45ff-a804-1765eeb837b4/part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td></tr><tr><td>1</td><td>Umang Bhatt</td><td>raksha87@example.org</td><td>Jaipur</td><td>Odisha</t ...

# %%
# %sql
-- 5 -- ICEBERG TABLE
CREATE TABLE cyntexa_dev.sales.customer_iceberg  USING ICEBERG AS
SELECT * FROM cyntexa_dev.sales.customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL cyntexa_dev.sales.customer_iceberg
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>iceberg</td><td>c3b15891-ee63-468f-99f4-e15dadd37a7c</td><td>cyntexa_dev.sales.customer_iceberg</td><td>null</td><td>s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/f11d14fb-8135-4299-807e-c956762e6de0</td><td>2026-08-24T11:20:33.427Z</td><td>2026-08-24T11:20:41.000Z</td><td>List()</td><td>List()</td><td>1</td><td>29759</td><td>Map(write.metadata.path -> s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/f11d14fb-8135-4299-807e-c956762e6de0/_iceberg/metadata, write.parquet.compression-codec -> zstd, write.summary.partition-limit -> 100, write.wap.enabled -> false, write.metadata.compression-codec -> gzip, write.object-storage.enabled -> true, history.expire.min-snapshots-to-keep -> 100, write.data.path -> s3://dbstorage-prod-iqnfz1vehn/uc/1873040a-3c95-4eb2-a6ae-35f45efd6136/474799a4-26b2-4b55-8346-8fcdb3e4653d/__unitystorage/catalogs/7cd1454a-98eb-4be2-a350-57c6bbd26b4a/tables/f11d14fb-8135-4299-807e-c956762e6de0, history.expire.max-snapshot-age-ms -> 0, gc.enabled -> false)</td><td>3</td><td>7</td><td>List(appendOnly, columnMapping, domainMetadata, icebergCompatV2, icebergWriterCompatV1, inCommitTimestamp, invariants, timestampNtz, typeWidening, v2Checkpoint, vacuumProtocolCheck)</td><td>Map()</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
-- 6
-- RECORD PER SOURCE FILE

SELECT _metadata.file_name AS source_file , COUNT(*) AS record_count FROM cyntexa_dev.sales.customer 
GROUP BY _metadata.file_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_file</th><th>record_count</th></tr></thead><tbody><tr><td>part-00000-5108da21-f438-4301-b972-5d3cb7ffb3f4.c000.zstd.parquet</td><td>1000</td></tr></tbody></table></div>

# %% [markdown]
# #ADVANCED

# %%
# %sql
-- 7 
--normal csv
SELECT product_id, product_name, category, price
FROM read_files(
  '/Volumes/cyntexa_dev/sales/raw/products_1_normal.csv',
  format => 'csv',
  header => true
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>category</th><th>price</th></tr></thead><tbody><tr><td>101</td><td>Laptop</td><td>Electronics</td><td>55000</td></tr><tr><td>102</td><td>Mouse</td><td>Accessories</td><td>800</td></tr><tr><td>103</td><td>Keyboard</td><td>Accessories</td><td>1500</td></tr><tr><td>104</td><td>Monitor</td><td>Electronics</td><td>12000</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM read_files(
    '/Volumes/cyntexa_dev/sales/raw/products_2_extra_column.csv',
    format => 'csv',
    header => true,
    schema => 'product_id INT, product_name STRING, category STRING, price INT',
    rescuedDataColumn => '_rescued_data'
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>category</th><th>price</th><th>_rescued_data</th></tr></thead><tbody><tr><td>105</td><td>Headphones</td><td>Accessories</td><td>2500</td><td>{"stock":"50","_file_path":"dbfs:/Volumes/cyntexa_dev/sales/raw/products_2_extra_column.csv"}</td></tr><tr><td>106</td><td>Printer</td><td>Electronics</td><td>15000</td><td>{"stock":"20","_file_path":"dbfs:/Volumes/cyntexa_dev/sales/raw/products_2_extra_column.csv"}</td></tr><tr><td>107</td><td>Webcam</td><td>Electronics</td><td>3500</td><td>{"stock":"35","_file_path":"dbfs:/Volumes/cyntexa_dev/sales/raw/products_2_extra_column.csv"}</td></tr><tr><td>108</td><td>USB Cable</td><td>Accessories</td><td>500</td><td>{"stock":"100","_file_path":"dbfs:/Volumes/cyntexa_dev/sales/raw/products_2_extra_column.csv"}</td></tr></tbody></table></div>

# %%
# %sql
-- different delimiter - specify the delimeter sign while reading the file .
SELECT * FROM read_files(
  '/Volumes/cyntexa_dev/sales/raw/products_3_semicolon.csv',
  format => 'csv',
  header => true,
  delimiter => ';'
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>category</th><th>price</th><th>_rescued_data</th></tr></thead><tbody><tr><td>109</td><td>Tablet</td><td>Electronics</td><td>25000</td><td>null</td></tr><tr><td>110</td><td>Speaker</td><td>Accessories</td><td>4500</td><td>null</td></tr><tr><td>111</td><td>Smart Watch</td><td>Wearables</td><td>7000</td><td>null</td></tr><tr><td>112</td><td>Power Bank</td><td>Accessories</td><td>1800</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# 8.
#
# Cyntexa choose Iceberg over Delta -
#  - if in a downstream cyntexa uses multiple compute engines like snowflake or trino as databricks provide a feature called delta Uniform through which a developer/enginner need not to copy the same table again and again. It provide a feature through which all multiple compute engines can use the same source.
#
#  - when a cyntexa not want to depend completely on databricks proprietary features. - if a company does not want to depend or completely rely on databricks platform it should move with the iceberg.
#
#  - want to avoid vendor lock-in.

# %%
# %sql
-- 9 
DESCRIBE HISTORY cyntexa_dev.sales.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>queryHistoryStatementId</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>0</td><td>2026-08-24T05:23:39.000Z</td><td>74586236074021</td><td>sakshijain7945@gmail.com</td><td>CREATE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.format.version":"2.12.0","delta.parquet.format.version.afe.internal":"2.12.0","delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(3964814146459404)</td><td>37c28831-5900-4d2b-9a80-95c3ea580d59</td><td>0824-052309-njao8cci-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1000, numOutputBytes -> 17693)</td><td>null</td><td>Databricks-Runtime/18.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>
